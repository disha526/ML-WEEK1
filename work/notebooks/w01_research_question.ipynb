# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/disha526/ML-WEEK1/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ## Lane: Refresh / Content Opportunity Scoring
#
# ## I'm choosing this lane because once I understood the data, this was the direction that made the most sense to me  there's a real backlog of pages that are declining or under visible, and a clear question of which ones deserve attention first.

# %%
"""I'm choosing this lane because once I understood the data, this was the direction that made the most sense to me
there's a real backlog of pages that are declining or under visible, and a clear question of which ones deserve attention
first."""
# Out:
# "I'm choosing this lane because once I understood the data, this was the direction that made the most sense to me\nthere's a real backlog of pages that are declining or under visible, and a clear question of which ones deserve attention\nfirst."

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ## This work helps a content/SEO manager decide which pages to prioritize for refresh or rewrite. If the recommendation is wrong, it costs the writing team's time on a page that didn't actually need it, the company's money on wasted effort, and a missed opportunity to fix a page that's genuinely losing visibility and traffic.

# %%
"""This work helps a content/SEO manager decide which pages to prioritize for refresh or rewrite.
If the recommendation is wrong, it costs the writing team's time on a page that didn't actually need it,
the company's money on wasted effort,and a missed opportunity to fix a page that's genuinely losing visibility
and traffic."""
# Out:
# "This work helps a content/SEO manager decide which pages to prioritize for refresh or rewrite.\nIf the recommendation is wrong, it costs the writing team's time on a page that didn't actually need it,\nthe company's money on wasted effort,and a missed opportunity to fix a page that's genuinely losing visibility\nand traffic."

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# ##Over half of pages are trending down despite sitting close to page 1, which suggests a real backlog worth prioritizing.

# %%
import pandas as pd
df = pd.read_csv('content_refresh_anonymized.csv')
print('Rows:', len(df))
print('% trending down:', round((df.trend_direction=='down').mean()*100, 1))
print('Median impressions_90d:', df.impressions_90d.median())
print('Median avg_position:', df.avg_position.median())
# Out:
# Rows: 30000
# % trending down: 54.2
# Median impressions_90d: 731.0
# Median avg_position: 10.8

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ##My model can say that a page shows signs of declining visibility and matches patterns seen in other underperforming pages  this is an observed pattern. But it cannot say that refreshing the page will cause traffic to go up, because the data never tracked a before/after refresh  it's just a snapshot of how pages looked, not proof of what fixing them does.

# %%
"""My model can say that a page shows signs of declining visibility and matches patterns seen in other
underperforming pages  this is an observed pattern. But it cannot say that refreshing the page will
cause traffic to go up, because the data never tracked a before/after refresh  it's just a snapshot
 of how pages looked, not proof of what fixing them does."""
# Out:
# "My model can say that a page shows signs of declining visibility and matches patterns seen in other\nunderperforming pages  this is an observed pattern. But it cannot say that refreshing the page will\ncause traffic to go up, because the data never tracked a before/after refresh  it's just a snapshot\n of how pages looked, not proof of what fixing them does."

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
